# %%
from datetime import datetime

# references for abbreviations! :
# http://strftime.org/

# %% [markdown]
# Convert a single string to datetime

# %%
# http://strftime.org/

datetime_object = datetime.strptime('Jun 1 2005  1:33PM', '%b %d %Y %I:%M%p')
datetime_object
# Out:
# datetime.datetime(2005, 6, 1, 13, 33)

# %% [markdown]
# Extract a unit (e.g., year)

# %%
datetime_object.year
# Out:
# 2005

# %%
datetime_object.hour
# Out:
# 13

# %% [markdown]
# Convert pandas column to datetime

# %%
import pandas as pd

df = pd.read_csv("/Users/avahoffman/Dropbox/Insight/Insight_data_challenges/18C/data_challenge_4/redcard_1.csv")

# make a new column
df['birthdate'] = pd.to_datetime(df['birthday'], format='%d.%m.%Y', errors='ignore')
# Produces 'NaT' if cell is empty
# df['birthdate'] =  pd.to_datetime(df['birthday'], format='%d.%m.%Y', errors='coerce') 

# remove old column if needed
# df = df.drop(['birthday'], axis=1)

df.head()
# Out:
#    Unnamed: 0    playerShort         player             club leagueCountry  \
# 0           0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain
# 1           1     john-utaka     John Utaka  Montpellier HSC        France
# 2           2    abdon-prats    Abdón Prats     RCD Mallorca         Spain
# 3           3     pablo-mari     Pablo Marí     RCD Mallorca         Spain
# 4           4     ruben-pena     Rubén Peña  Real Valladolid         Spain
#
#    height  weight              position  games  victories    ...      refNum  \
# 0   177.0    72.0  Attacking Midfielder      1          0    ...           1
# 1   179.0    82.0          Right Winger      1          0    ...           2
# 2   181.0    79.0                   NaN      1          0    ...           3
# 3   191.0    87.0           Center Back      1          1    ...           3
# 4   172.0    70.0      Right Midfielder      1          1    ...           3
#
#    refCountry  Alpha_3   meanIAT    nIAT     seIAT   meanExp    nExp  \
# 0           1      GRC  0.326391   712.0  0.000564  0.396000   750.0
# 1           2      ZMB  0.203375    40.0  0.010875 -0.204082    49.0
# 2           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 3           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
# 4           3      ESP  0.369894  1785.0  0.000229  0.588297  1897.0
#
#       seExp  birthdate
# 0  0.002696 1983-08-31
# 1  0.061504 1982-01-08
# 2  0.001002 1992-12-17
# 3  0.001002 1993-08-31
# 4  0.001002 1991-07-18
#
# [5 rows x 29 columns]

# %% [markdown]
# Extract year, month etc into new columns

# %%
df['year'], df['month'] = df['birthdate'].dt.year, df['birthdate'].dt.month
df.head()
# Out:
#    Unnamed: 0    playerShort         player             club leagueCountry  \
# 0           0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain
# 1           1     john-utaka     John Utaka  Montpellier HSC        France
# 2           2    abdon-prats    Abdón Prats     RCD Mallorca         Spain
# 3           3     pablo-mari     Pablo Marí     RCD Mallorca         Spain
# 4           4     ruben-pena     Rubén Peña  Real Valladolid         Spain
#
#    height  weight              position  games  victories  ...    Alpha_3  \
# 0   177.0    72.0  Attacking Midfielder      1          0  ...        GRC
# 1   179.0    82.0          Right Winger      1          0  ...        ZMB
# 2   181.0    79.0                   NaN      1          0  ...        ESP
# 3   191.0    87.0           Center Back      1          1  ...        ESP
# 4   172.0    70.0      Right Midfielder      1          1  ...        ESP
#
#     meanIAT    nIAT     seIAT   meanExp    nExp     seExp  birthdate  year  \
# 0  0.326391   712.0  0.000564  0.396000   750.0  0.002696 1983-08-31  1983
# 1  0.203375    40.0  0.010875 -0.204082    49.0  0.061504 1982-01-08  1982
# 2  0.369894  1785.0  0.000229  0.588297  1897.0  0.001002 1992-12-17  1992
# 3  0.369894  1785.0  0.000229  0.588297  1897.0  0.001002 1993-08-31  1993
# 4  0.369894  1785.0  0.000229  0.588297  1897.0  0.001002 1991-07-18  1991
#
#    month
# 0      8
# 1      1
# 2     12
# 3      8
# 4      7
#
# [5 rows x 31 columns]

# %% [markdown]
# numbers to month name

# %%
import calendar

df['month_name'] = df['month'].apply(lambda x: calendar.month_abbr[x])

df.head()
# Out:
#    Unnamed: 0    playerShort         player             club leagueCountry  \
# 0           0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain
# 1           1     john-utaka     John Utaka  Montpellier HSC        France
# 2           2    abdon-prats    Abdón Prats     RCD Mallorca         Spain
# 3           3     pablo-mari     Pablo Marí     RCD Mallorca         Spain
# 4           4     ruben-pena     Rubén Peña  Real Valladolid         Spain
#
#    height  weight              position  games  victories     ...        nIAT  \
# 0   177.0    72.0  Attacking Midfielder      1          0     ...       712.0
# 1   179.0    82.0          Right Winger      1          0     ...        40.0
# 2   181.0    79.0                   NaN      1          0     ...      1785.0
# 3   191.0    87.0           Center Back      1          1     ...      1785.0
# 4   172.0    70.0      Right Midfielder      1          1     ...      1785.0
#
#       seIAT   meanExp    nExp     seExp  birthdate  year  month   age  \
# 0  0.000564  0.396000   750.0  0.002696 1983-08-31  1983      8  35.0
# 1  0.010875 -0.204082    49.0  0.061504 1982-01-08  1982      1  36.0
# 2  0.000229  0.588297  1897.0  0.001002 1992-12-17  1992     12  25.0
# 3  0.000229  0.588297  1897.0  0.001002 1993-08-31  1993      8  25.0
# 4  0.000229  0.588297  1897.0  0.001002 1991-07-18  1991      7  27.0
#
#    month_name
# 0         Aug
# 1         Jan
# 2         Dec
# 3         Aug
# 4         Jul
#
# [5 rows x 33 columns]

# %% [markdown]
# Calculate age / duration

# %%
now = pd.Timestamp(datetime.now())

df['age'] = (now - df['birthdate']).astype('<m8[Y]')

df.head()
# Out:
#    Unnamed: 0    playerShort         player             club leagueCountry  \
# 0           0  lucas-wilchez  Lucas Wilchez    Real Zaragoza         Spain
# 1           1     john-utaka     John Utaka  Montpellier HSC        France
# 2           2    abdon-prats    Abdón Prats     RCD Mallorca         Spain
# 3           3     pablo-mari     Pablo Marí     RCD Mallorca         Spain
# 4           4     ruben-pena     Rubén Peña  Real Valladolid         Spain
#
#    height  weight              position  games  victories  ...    meanIAT  \
# 0   177.0    72.0  Attacking Midfielder      1          0  ...   0.326391
# 1   179.0    82.0          Right Winger      1          0  ...   0.203375
# 2   181.0    79.0                   NaN      1          0  ...   0.369894
# 3   191.0    87.0           Center Back      1          1  ...   0.369894
# 4   172.0    70.0      Right Midfielder      1          1  ...   0.369894
#
#      nIAT     seIAT   meanExp    nExp     seExp  birthdate  year  month   age
# 0   712.0  0.000564  0.396000   750.0  0.002696 1983-08-31  1983      8  35.0
# 1    40.0  0.010875 -0.204082    49.0  0.061504 1982-01-08  1982      1  36.0
# 2  1785.0  0.000229  0.588297  1897.0  0.001002 1992-12-17  1992     12  25.0
# 3  1785.0  0.000229  0.588297  1897.0  0.001002 1993-08-31  1993      8  25.0
# 4  1785.0  0.000229  0.588297  1897.0  0.001002 1991-07-18  1991      7  27.0
#
# [5 rows x 32 columns]
